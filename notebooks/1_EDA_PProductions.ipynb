# %% [markdown]
# # EDA PProductions

# %% [markdown]
# Análise exploratória dos dados fornecidos pela PProductions

# %% [markdown]
# ### Limpeza dos dados

# %%
# Importando as bibliotecas

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
# Lendo os dados

df = pd.read_csv('https://raw.githubusercontent.com/pat-weber/lighthouse/main/lighthouse_project/data/desafio_indicium_imdb.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     999 non-null    int64
#  1   Series_Title   999 non-null    object
#  2   Released_Year  999 non-null    object
#  3   Certificate    898 non-null    object
#  4   Runtime        999 non-null    object
#  5   Genre          999 non-null    object
#  6   IMDB_Rating    999 non-null    float64
#  7   Overview       999 non-null    object
#  8   Meta_score     842 non-null    float64
#  9   Director       999 non-null    object
#  10  Star1          999 non-null    object
#  11  Star2          999 non-null    object
#  12  Star3          999 non-null    object
#  13  Star4          999 non-null    object
#  14  No_of_Votes    999 non-null    int64
#  15  Gross          830 non-null    object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 125.0+ KB

# %%
# Visualizando o data frame

df.head(30)
# Out:
#     Unnamed: 0                                       Series_Title  \
# 0            1                                      The Godfather
# 1            2                                    The Dark Knight
# 2            3                             The Godfather: Part II
# 3            4                                       12 Angry Men
# 4            5      The Lord of the Rings: The Return of the King
# 5            6                                       Pulp Fiction
# 6            7                                   Schindler's List
# 7            8                                          Inception
# 8            9                                         Fight Club
# 9           10  The Lord of the Rings: The Fellowship of the Ring
# 10          11                                       Forrest Gump
# 11          12                    Il buono, il brutto, il cattivo
# 12          13              The Lord of the Rings: The Two Towers
# 13          14                                         The Matrix
# 14          15                                         Goodfellas
# 15          16     Star Wars: Episode V - The Empire Strikes Back
# 16          17                    One Flew Over the Cuckoo's Nest
# 17          18                                           Hamilton
# 18          19                                       Gisaengchung
# 19          20                                    Soorarai Pottru
# 20          21                                       Interstellar
# 21          22                                     Cidade de Deus
# 22          23                      Sen to Chihiro no kamikakushi
# 23          24                                Saving Private Ryan
# 24          25                                     The Green Mile
# 25          26                                    La vita è bella
# 26          27                                              Se7en
# 27          28                           The Silence of the Lambs
# 28          29                                          Star Wars
# 29          30                                            Seppuku
#
#    Released_Year Certificate  Runtime                         Genre  \
# 0           1972           A  175 min                  Crime, Drama
# 1           2008          UA  152 min          Action, Crime, Drama
# 2           1974           A  202 min                  Crime, Drama
# 3           1957           U   96 min                  Crime, Drama
# 4           2003           U  201 min      Action, Adventure, Drama
# 5           1994           A  154 min                  Crime, Drama
# 6           1993           A  195 min     Biography, Drama, History
# 7           2010          UA  148 min     Action, Adventure, Sci-Fi
# 8           1999           A  139 min                         Drama
# 9           2001           U  178 min      Action, Adventure, Drama
# 10          1994          UA  142 min                Drama, Romance
# 11          1966           A  161 min                       Western
# 12          2002          UA  179 min      Action, Adventure, Drama
# 13          1999           A  136 min                Action, Sci-Fi
# 14          1990           A  146 min       Biography, Crime, Drama
# 15          1980          UA  124 min    Action, Adventure, Fantasy
# 16          1975           A  133 min                         Drama
# 17          2020       PG-13  160 min     Biography, Drama, History
# 18          2019           A  132 min       Comedy, Drama, Thriller
# 19          2020           U  153 min                         Drama
# 20          2014          UA  169 min      Adventure, Drama, Sci-Fi
# 21          2002           A  130 min                  Crime, Drama
# 22          2001           U  125 min  Animation, Adventure, Family
# 23          1998           R  169 min                    Drama, War
# 24          1999           A  189 min         Crime, Drama, Fantasy
# 25          1997           U  116 min        Comedy, Drama, Romance
# 26          1995           A  127 min         Crime, Drama, Mystery
# 27          1991           A  118 min        Crime, Drama, Thriller
# 28          1977          UA  121 min    Action, Adventure, Fantasy
# 29          1962         NaN  133 min        Action, Drama, Mystery
#
#     IMDB_Rating                                           Overview  \
# 0           9.2  An organized crime dynasty's aging patriarch t...
# 1           9.0  When the menace known as the Joker wreaks havo...
# 2           9.0  The early life and career of Vito Corleone in ...
# 3           9.0  A jury holdout attempts to prevent a miscarria...
# 4           8.9  Gandalf and Aragorn lead the World of Men agai...
# 5           8.9  The lives of two mob hitmen, a boxer, a gangst...
# 6           8.9  In German-occupied Poland during World War II,...
# 7           8.8  A thief who steals corporate secrets through t...
# 8           8.8  An insomniac office worker and a devil-may-car...
# 9           8.8  A meek Hobbit from the Shire and eight compani...
# 10          8.8  The presidencies of Kennedy and Johnson, the e...
# 11          8.8  A bounty hunting scam joins two men in an unea...
# 12          8.7  While Frodo and Sam edge closer to Mordor with...
# 13          8.7  When a beautiful stranger leads computer hacke...
# 14          8.7  The story of Henry Hill and his life in the mo...
# 15          8.7  After the Rebels are brutally overpowered by t...
# 16          8.7  A criminal pleads insanity and is admitted to ...
# 17          8.6  The real life of one of America's foremost fou...
# 18          8.6  Greed and class discrimination threaten the ne...
# 19          8.6  Nedumaaran Rajangam "Maara" sets out to make t...
# 20          8.6  A team of explorers travel through a wormhole ...
# 21          8.6  In the slums of Rio, two kids' paths diverge a...
# 22          8.6  During her family's move to the suburbs, a sul...
# 23          8.6  Following the Normandy Landings, a group of U....
# 24          8.6  The lives of guards on Death Row are affected ...
# 25          8.6  When an open-minded Jewish librarian and his s...
# 26          8.6  Two detectives, a rookie and a veteran, hunt a...
# 27          8.6  A young F.B.I. cadet must receive the help of ...
# 28          8.6  Luke Skywalker joins forces with a Jedi Knight...
# 29          8.6  When a ronin requesting seppuku at a feudal lo...
#
#     Meta_score              Director                Star1  \
# 0        100.0  Francis Ford Coppola        Marlon Brando
# 1         84.0     Christopher Nolan       Christian Bale
# 2         90.0  Francis Ford Coppola            Al Pacino
# 3         96.0          Sidney Lumet          Henry Fonda
# 4         94.0         Peter Jackson          Elijah Wood
# 5         94.0     Quentin Tarantino        John Travolta
# 6         94.0      Steven Spielberg          Liam Neeson
# 7         74.0     Christopher Nolan    Leonardo DiCaprio
# 8         66.0         David Fincher            Brad Pitt
# 9         92.0         Peter Jackson          Elijah Wood
# 10        82.0       Robert Zemeckis            Tom Hanks
# 11        90.0          Sergio Leone       Clint Eastwood
# 12        87.0         Peter Jackson          Elijah Wood
# 13        73.0        Lana Wachowski      Lilly Wachowski
# 14        90.0       Martin Scorsese       Robert De Niro
# 15        82.0        Irvin Kershner          Mark Hamill
# 16        83.0          Milos Forman       Jack Nicholson
# 17        90.0           Thomas Kail   Lin-Manuel Miranda
# 18        96.0          Bong Joon Ho         Kang-ho Song
# 19         NaN         Sudha Kongara               Suriya
# 20        74.0     Christopher Nolan  Matthew McConaughey
# 21        79.0    Fernando Meirelles           Kátia Lund
# 22        96.0        Hayao Miyazaki        Daveigh Chase
# 23        91.0      Steven Spielberg            Tom Hanks
# 24        61.0        Frank Darabont            Tom Hanks
# 25        59.0       Roberto Benigni      Roberto Benigni
# 26        65.0         David Fincher       Morgan Freeman
# 27        85.0        Jonathan Demme         Jodie Foster
# 28        90.0          George Lucas          Mark Hamill
# 29        85.0      Masaki Kobayashi      Tatsuya Nakadai
#
#                     Star2               Star3                   Star4  \
# 0               Al Pacino          James Caan            Diane Keaton
# 1            Heath Ledger       Aaron Eckhart           Michael Caine
# 2          Robert De Niro       Robert Duvall            Diane Keaton
# 3             Lee J. Cobb       Martin Balsam            John Fiedler
# 4         Viggo Mortensen        Ian McKellen           Orlando Bloom
# 5             Uma Thurman   Samuel L. Jackson            Bruce Willis
# 6           Ralph Fiennes        Ben Kingsley        Caroline Goodall
# 7    Joseph Gordon-Levitt         Elliot Page            Ken Watanabe
# 8           Edward Norton           Meat Loaf            Zach Grenier
# 9            Ian McKellen       Orlando Bloom               Sean Bean
# 10           Robin Wright         Gary Sinise             Sally Field
# 11            Eli Wallach       Lee Van Cleef            Aldo Giuffrè
# 12           Ian McKellen     Viggo Mortensen           Orlando Bloom
# 13           Keanu Reeves  Laurence Fishburne        Carrie-Anne Moss
# 14             Ray Liotta           Joe Pesci         Lorraine Bracco
# 15          Harrison Ford       Carrie Fisher      Billy Dee Williams
# 16        Louise Fletcher    Michael Berryman            Peter Brocco
# 17           Phillipa Soo     Leslie Odom Jr.  Renée Elise Goldsberry
# 18           Lee Sun-kyun       Cho Yeo-jeong            Choi Woo-sik
# 19               Madhavan        Paresh Rawal       Aparna Balamurali
# 20          Anne Hathaway    Jessica Chastain           Mackenzie Foy
# 21    Alexandre Rodrigues     Leandro Firmino    Matheus Nachtergaele
# 22      Suzanne Pleshette          Miyu Irino            Rumi Hiiragi
# 23             Matt Damon        Tom Sizemore            Edward Burns
# 24  Michael Clarke Duncan         David Morse             Bonnie Hunt
# 25      Nicoletta Braschi   Giorgio Cantarini         Giustino Durano
# 26              Brad Pitt        Kevin Spacey     Andrew Kevin Walker
# 27        Anthony Hopkins  Lawrence A. Bonney            Kasi Lemmons
# 28          Harrison Ford       Carrie Fisher           Alec Guinness
# 29         Akira Ishihama      Shima Iwashita           Tetsurô Tanba
#
#     No_of_Votes        Gross
# 0       1620367  134,966,411
# 1       2303232  534,858,444
# 2       1129952   57,300,000
# 3        689845    4,360,000
# 4       1642758  377,845,905
# 5       1826188  107,928,762
# 6       1213505   96,898,818
# 7       2067042  292,576,195
# 8       1854740   37,030,102
# 9       1661481  315,544,750
# 10      1809221  330,252,182
# 11       688390    6,100,000
# 12      1485555  342,551,365
# 13      1676426  171,479,930
# 14      1020727   46,836,394
# 15      1159315  290,475,067
# 16       918088  112,000,000
# 17        55291          NaN
# 18       552778   53,367,844
# 19        54995          NaN
# 20      1512360  188,020,017
# 21       699256    7,563,397
# 22       651376   10,055,859
# 23      1235804  216,540,909
# 24      1147794  136,801,374
# 25       623629   57,598,247
# 26      1445096  100,125,643
# 27      1270197  130,742,922
# 28      1231473  322,740,140
# 29        42004          NaN

# %%
# Padronizando as colunas

df.columns = df.columns.str.lower()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   unnamed: 0     999 non-null    int64
#  1   series_title   999 non-null    object
#  2   released_year  999 non-null    object
#  3   certificate    898 non-null    object
#  4   runtime        999 non-null    object
#  5   genre          999 non-null    object
#  6   imdb_rating    999 non-null    float64
#  7   overview       999 non-null    object
#  8   meta_score     842 non-null    float64
#  9   director       999 non-null    object
#  10  star1          999 non-null    object
#  11  star2          999 non-null    object
#  12  star3          999 non-null    object
#  13  star4          999 non-null    object
#  14  no_of_votes    999 non-null    int64
#  15  gross          830 non-null    object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 125.0+ KB

# %%
# Um dado ausente no ano de lançamento sendo transformado em 0 para seguir com as análises

df['released_year'] = df['released_year'].replace('PG', 0)

# Transformando os dados dos anos em numéricos

df['released_year'] = df['released_year'].astype(int)
df['runtime'] = df['runtime'].str.replace('min', '').astype(int)
df['gross'] = df['gross'].str.replace(',', '').astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   unnamed: 0     999 non-null    int64
#  1   series_title   999 non-null    object
#  2   released_year  999 non-null    int64
#  3   certificate    898 non-null    object
#  4   runtime        999 non-null    int64
#  5   genre          999 non-null    object
#  6   imdb_rating    999 non-null    float64
#  7   overview       999 non-null    object
#  8   meta_score     842 non-null    float64
#  9   director       999 non-null    object
#  10  star1          999 non-null    object
#  11  star2          999 non-null    object
#  12  star3          999 non-null    object
#  13  star4          999 non-null    object
#  14  no_of_votes    999 non-null    int64
#  15  gross          830 non-null    float64
# dtypes: float64(3), int64(4), object(9)
# memory usage: 125.0+ KB

# %%
# Visualizando os valores médios e a mediana da coluna de faturamento

print(df['gross'].mean())
print(df['gross'].median())
# Out:
# 68082574.10481928
# 23457439.5

# %% [markdown]
# Os valores ausentes de faturamento impactarão nas análises e modelagens que serão feitas, uma vez que um filme ter 0 como faturamento não é factível. Esses valores ausentes serão preenchidos com o valor mediano, assim os valores dos filmes que atingiram picos de bilheteria muito acima da média não influenciarão tanto na definição dos valores ausentes.
#
# A mesma abordagem se dará para os valores ausentes nas avaliações da coluna meta_score.

# %%
# Preenchendo valores ausentes com o valor mediano nas colunas de faturamento e avaliações

df['gross'] = df['gross'].fillna(df['gross'].median())
df['meta_score'] = df['meta_score'].fillna(df['meta_score'].median())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   unnamed: 0     999 non-null    int64
#  1   series_title   999 non-null    object
#  2   released_year  999 non-null    int64
#  3   certificate    898 non-null    object
#  4   runtime        999 non-null    int64
#  5   genre          999 non-null    object
#  6   imdb_rating    999 non-null    float64
#  7   overview       999 non-null    object
#  8   meta_score     999 non-null    float64
#  9   director       999 non-null    object
#  10  star1          999 non-null    object
#  11  star2          999 non-null    object
#  12  star3          999 non-null    object
#  13  star4          999 non-null    object
#  14  no_of_votes    999 non-null    int64
#  15  gross          999 non-null    float64
# dtypes: float64(3), int64(4), object(9)
# memory usage: 125.0+ KB

# %% [markdown]
# ### Análise dos dados

# %% [markdown]
# Em um primeiro olhar para os dados vamos visualizar a distribuição dos filmes por ano de lançamento e situar as faixas de faturamento para definir o que é considerado média ou alta receita.

# %%
# Visualizando lançamentos de filmes por ano
# Existe um título com esse valor ausente, como não excluímos ele da base de dados, vamos tirá-lo apenas deste gráfico

df = df[df['released_year'] != 0]

grouped_df = df.groupby('released_year')['series_title'].count()

plt.bar(grouped_df.index, grouped_df.values)
plt.xlabel('Ano')
plt.ylabel('Nº de lançamentos')
plt.title('Número de lançamentos por ano')
plt.show()

# %% [markdown]
# O gráfico mostra um aumento signficativo de lançamento a partir do final dos anos 90. Essa foi a época em que as tecnologias de captação e edição digitais tomaram espaço na indústria, surgem mais filmes de animação e com efeitos especiais.
# Para exemplo desta afirmação, vamos ver este mesmo gráfico com somente os filmes do gênero animação.

# %%
# Filtrar os filmes que contêm "Animation" no gênero
df_animation = df[df['genre'].str.contains('Animation', case=False, na=False)]

# Remover filmes com ano de lançamento 0 (se houver)
df_animation = df_animation[df_animation['released_year'] != 0]

# Agrupar por ano e contar o número de filmes
grouped_df = df_animation.groupby('released_year')['series_title'].count()

# Plotar o gráfico
plt.bar(grouped_df.index, grouped_df.values)
plt.xlabel('Ano de Lançamento')
plt.ylabel('Número de Filmes de Animação')
plt.title('Número de Filmes de Animação Lançados por Ano')
plt.show()

# %% [markdown]
# A maior parte dos filmes de animação foram lançados do final dos anos 80 em diante.
#
# Agora vamos analisar números de faturamento dos filmes.

# %%
# Visualizando um histograma de faixas de faturamento

plt.hist(df['gross'], bins=10)
plt.xlabel('Faturamento (100 milhões)')
plt.ylabel('Número de filmes')
plt.title('Número de filmes por faixa de faturamento')
plt.show()

# %% [markdown]
# A maior parte dos filmes não passa de 150 milhões de faturamento. Alguns títulos alcançaram 600 milhões ou mais, vamos olhar para eles.

# %%
# Selecionando os filmes que faturaram mais que 600 milhões

df_gross = df[df['gross'] > 600000000]
df_gross = df_gross.sort_values(by='gross', ascending=False)

# Imprimindo o número de linhas e colunas do DataFrame filtrado
print(df_gross.shape)

# Imprimindo informações sobre os filmes com maior faturamento
df_gross = df_gross[['series_title', 'released_year', 'director', 'gross', 'genre']]

df_gross
# Out:
# (7, 16)
#                                    series_title  released_year       director  \
# 476  Star Wars: Episode VII - The Force Awakens           2015    J.J. Abrams
# 58                            Avengers: Endgame           2019  Anthony Russo
# 622                                      Avatar           2009  James Cameron
# 59                       Avengers: Infinity War           2018  Anthony Russo
# 651                                     Titanic           1997  James Cameron
# 356                                The Avengers           2012    Joss Whedon
# 890                               Incredibles 2           2018      Brad Bird
#
#            gross                         genre
# 476  936662225.0     Action, Adventure, Sci-Fi
# 58   858373000.0      Action, Adventure, Drama
# 622  760507625.0    Action, Adventure, Fantasy
# 59   678815482.0     Action, Adventure, Sci-Fi
# 651  659325379.0                Drama, Romance
# 356  623279547.0     Action, Adventure, Sci-Fi
# 890  608581744.0  Animation, Action, Adventure

# %% [markdown]
# 7 filmes passaram da marca de 600 milhões, 3 deles da série Avengers que assim como Star Wars, Avatar e Os Incríveis 2, entram no gênero de ação e aventura. O único título que fica fora desta categoria é Titanic. Também é o único filme lançado antes da década de 2000.
#
# Destes 7 filmes, 4 deles são continuações de sequências.

# %%
# Visualizando a correlação entre ano de lançamento e faturamento

sns.scatterplot(x='released_year', y='gross', data=df)
plt.show()

# %% [markdown]
# Existe uma correlação entre ano de lançamento e faturamento, o que é explicado pela popularização das salas de cinema, que alcança um público maior.
# Porém, um filme faturar 200 milhões em 1940, não é a mesma coisa que 200 milhões nos anos 2000. Este título de 1940 claramente se destacou mais do que tantos filmes que obtiveram essa marca nos últimos anos.
#
# Vamos olhar para os outliers por década.

# %%
# Ordenando por faturamento

df_gross = df.sort_values(by='gross', ascending=False)

# Criando a coluna de década
df_gross['decade'] = (df_gross['released_year'] // 10) * 10

# Selecionando os 3 filmes com maior faturamento por década
df_top_3_gross = df_gross.groupby('decade').apply(lambda x: x.nlargest(3, 'gross'), include_groups=False).reset_index(drop=True)

# Selecionando as colunas desejadas
df_top_3_gross = df_top_3_gross[['series_title', 'director', 'released_year', 'genre']]

# Exibindo os resultados
df_top_3_gross
# Out:
#                                       series_title             director  \
# 0                     Das Cabinet des Dr. Caligari         Robert Wiene
# 1                                       The Circus      Charles Chaplin
# 2                                        Nosferatu          F.W. Murnau
# 3                               Gone with the Wind       Victor Fleming
# 4                                The Invisible Man          James Whale
# 5                                     The 39 Steps     Alfred Hitchcock
# 6                                         Fantasia          James Algar
# 7                      The Best Years of Our Lives        William Wyler
# 8                                         Lifeboat     Alfred Hitchcock
# 9                             The Ten Commandments     Cecil B. DeMille
# 10                                         Ben-Hur        William Wyler
# 11                    The Bridge on the River Kwai           David Lean
# 12                              The Sound of Music          Robert Wise
# 13                                 The Jungle Book  Wolfgang Reitherman
# 14                                  Doctor Zhivago           David Lean
# 15                                       Star Wars         George Lucas
# 16                                            Jaws     Steven Spielberg
# 17                                    The Exorcist     William Friedkin
# 18                      E.T. the Extra-Terrestrial     Steven Spielberg
# 19      Star Wars: Episode VI - Return of the Jedi     Richard Marquand
# 20  Star Wars: Episode V - The Empire Strikes Back       Irvin Kershner
# 21                                         Titanic        James Cameron
# 22                                   The Lion King         Roger Allers
# 23                                   Jurassic Park     Steven Spielberg
# 24                                          Avatar        James Cameron
# 25                                 The Dark Knight    Christopher Nolan
# 26                                    Finding Nemo       Andrew Stanton
# 27      Star Wars: Episode VII - The Force Awakens          J.J. Abrams
# 28                               Avengers: Endgame        Anthony Russo
# 29                          Avengers: Infinity War        Anthony Russo
# 30                                     Dil Bechara       Mukesh Chhabra
# 31                                            Soul          Pete Docter
# 32                                 Soorarai Pottru        Sudha Kongara
#
#     released_year                         genre
# 0            1920      Fantasy, Horror, Mystery
# 1            1928               Comedy, Romance
# 2            1922               Fantasy, Horror
# 3            1939       Drama, History, Romance
# 4            1933                Horror, Sci-Fi
# 5            1935      Crime, Mystery, Thriller
# 6            1940    Animation, Family, Fantasy
# 7            1946           Drama, Romance, War
# 8            1944                    Drama, War
# 9            1956              Adventure, Drama
# 10           1959     Adventure, Drama, History
# 11           1957         Adventure, Drama, War
# 12           1965      Biography, Drama, Family
# 13           1967  Animation, Adventure, Family
# 14           1965           Drama, Romance, War
# 15           1977    Action, Adventure, Fantasy
# 16           1975           Adventure, Thriller
# 17           1973                        Horror
# 18           1982                Family, Sci-Fi
# 19           1983    Action, Adventure, Fantasy
# 20           1980    Action, Adventure, Fantasy
# 21           1997                Drama, Romance
# 22           1994   Animation, Adventure, Drama
# 23           1993     Action, Adventure, Sci-Fi
# 24           2009    Action, Adventure, Fantasy
# 25           2008          Action, Crime, Drama
# 26           2003  Animation, Adventure, Comedy
# 27           2015     Action, Adventure, Sci-Fi
# 28           2019      Action, Adventure, Drama
# 29           2018     Action, Adventure, Sci-Fi
# 30           2020        Comedy, Drama, Romance
# 31           2020  Animation, Adventure, Comedy
# 32           2020                         Drama

# %%
# Dividindo a coluna de gêneros em listas
df_top_3_gross['genre_list'] = df_top_3_gross['genre'].str.split(', ')

# Criando uma série com todas as listas de gêneros
genre_series = df_top_3_gross['genre_list'].explode()

# Criando dummies para cada gênero
genre_dummies = pd.get_dummies(genre_series).groupby(level=0).sum()

# Somando as colunas para obter a contagem de cada gênero
genre_counts = genre_dummies.sum()

# Convertendo o resultado para um DataFrame para melhor visualização
top_3_genre_counts_df = genre_counts.sort_values(ascending= False).reset_index()
top_3_genre_counts_df.columns = ['Genre', 'Count']

plt.figure(figsize=(10, 6))
plt.bar(top_3_genre_counts_df['Genre'], top_3_genre_counts_df['Count'])
plt.xlabel('Gênero')
plt.ylabel('Contagem')
plt.title('Contagem de Gêneros nos Top 3 Filmes com Maior Faturamento por Década')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Estes são os gêneros que mais aparecem entre os filmes de maior faturamento de cada década. Aventura e drama se destacam. Importante ressaltar que um filme pode ser classificado em mais de gênero, um biografia pode ser classificada também como drama, por exemplo. Então esta contagem no gráfico acima representa o número de ocorrências em que um filme foi classificado em um gênero, sendo que esse filme também poderá ser contabilizado em outros gêneros.
#
# Agora vamos fazer um recorte de datas mais próximas da atualidade com objetivo de promover insights para o mercado contemporâneo de produções.

# %%
# Filtrando filmes lançados a partir de 1980
df_80_filtered = df[df['released_year'] >= 1980].copy()

# Dividindo a coluna de gêneros em listas
df_80_filtered.loc[:, 'genre_list'] = df_80_filtered['genre'].str.split(', ')

# Explodindo a coluna de listas de gêneros para que cada filme apareça várias vezes, uma para cada gênero
df_exploded = df_80_filtered.explode('genre_list')

# %%
# Ordenando e contando as ocorrências de gênero

genre_counts = df_exploded['genre_list'].value_counts().reset_index()
genre_counts.columns = ['genre', 'count']

# Ordenando os gêneros pelo número de filmes em ordem decrescente
genre_counts = genre_counts.sort_values(by='count', ascending=False).reset_index(drop=True)

# Plotando o gráfico
plt.figure(figsize=(12, 8))
plt.bar(genre_counts['genre'], genre_counts['count'])
plt.xlabel('Gênero')
plt.ylabel('Ocorrência em Filmes')
plt.title('Filmes por Gênero desde 1980')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# A mesma metodologia de contagem aplicada com os filmes lançados de 1980 em diante.

# %%
# Agrupando pelo gênero e somar o faturamento
genre_gross = df_exploded.groupby('genre_list')['gross'].sum().reset_index()

# Ordenando os gêneros pelo faturamento em ordem decrescente
genre_gross = genre_gross.sort_values(by='gross', ascending=False).reset_index(drop=True)

# Convertendo o número de faturamento para melhor visualização
pd.options.display.float_format = '{:,.2f}'.format

# Plotando o gráfico 

plt.figure(figsize=(12, 8))
plt.bar(genre_gross['genre_list'], genre_gross['gross'])
plt.xlabel('Gênero')
plt.ylabel('Faturamento (em bilhões)')
plt.title('Arrecadação por Gênero desde 1980')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Enquanto que na ocorrência do gênero de filmes lançados o gênero drama se destaca isolado dos outros, no montate de faturamento o gênero mais expressivo nos últimos anos é aventura, porém não isolado no topo. Aventura, drama e ação estão em um patamar de faturamento próximo, enquanto que comédia e os outros seguem abaixo.

# %%
genre_mean_gross = df_exploded.groupby('genre_list')['gross'].mean().reset_index()
genre_mean_gross.columns = ['Genre', 'Mean Gross']

genre_mean_gross = genre_mean_gross.sort_values(by='Mean Gross', ascending=False)


plt.figure(figsize=(12, 6))
plt.bar(genre_mean_gross['Genre'], genre_mean_gross['Mean Gross'])
plt.title('Média de Faturamento por Gênero (Filmes a partir de 1980)')
plt.xlabel('Gênero')
plt.ylabel('Média de Faturamento (em bilhões)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Apesar da ocorrência de filmes de drama se destacar com faturamento alto, a média de faturamento é mais baixa que a maioria dos gêneros.
#
# Vamos confirmar se filmes de aventura faturam mais que filmes de drama testando a hipótese.

# %%
# Hipótese 0 é de que as médias de faturamento são iguais

# Filtrando os dados para obter apenas filmes de aventura e drama
df_aventura = df[df['genre'].str.contains('Adventure')]
df_drama = df[df['genre'].str.contains('Drama')]

# Selecionando apenas a coluna de faturamento para cada grupo
faturamento_aventura = df_aventura['gross']
faturamento_drama = df_drama['gross']

# Realizando o teste t de Student para amostras independentes
t_statistic, p_value = stats.ttest_ind(faturamento_aventura, faturamento_drama)

# Nível de significância é 0.05
alpha = 0.05

# Comparando o valor p com o nível de significância
if p_value < alpha:
    print("Rejeitar H0: As médias de faturamento de aventura e drama são diferentes.")
else:
    print("Não há evidências suficientes para rejeitar H0: Não podemos concluir que as médias de faturamento de aventura e drama são diferentes.")
# Out:
# Rejeitar H0: As médias de faturamento de aventura e drama são diferentes.

# %% [markdown]
# Confirmado o que o gráfico mostrou: muitos filmes são classificados como drama, mas o gênero com maior faturamento é aventura.
#
# Também corroborado pela lista dos filmes com faturamento maior que 600 milhões, em que 6 títulos dentre 7 são classificados como ação e aventura.

# %%
df_gross
# Out:
#      unnamed: 0                                series_title  released_year  \
# 476         477  Star Wars: Episode VII - The Force Awakens           2015
# 58           59                           Avengers: Endgame           2019
# 622         623                                      Avatar           2009
# 59           60                      Avengers: Infinity War           2018
# 651         652                                     Titanic           1997
# ..          ...                                         ...            ...
# 604         605                                     Ajeossi           2010
# 925         926                            Dead Man's Shoes           2004
# 623         624                                  Mr. Nobody           2009
# 389         390                   Knockin' on Heaven's Door           1997
# 629         630                                 Adams æbler           2005
#
#     certificate  runtime                       genre  imdb_rating  \
# 476           U      138   Action, Adventure, Sci-Fi         7.90
# 58           UA      181    Action, Adventure, Drama         8.40
# 622          UA      162  Action, Adventure, Fantasy         7.80
# 59           UA      149   Action, Adventure, Sci-Fi         8.40
# 651          UA      194              Drama, Romance         7.80
# ..          ...      ...                         ...          ...
# 604           R      119        Action, Crime, Drama         7.80
# 925         NaN       90      Crime, Drama, Thriller         7.60
# 623           R      141     Drama, Fantasy, Romance         7.80
# 389         NaN       87       Action, Crime, Comedy         8.00
# 629           R       94        Comedy, Crime, Drama         7.80
#
#                                               overview  meta_score  \
# 476  As a new threat to the galaxy rises, Rey, a de...       80.00
# 58   After the devastating events of Avengers: Infi...       78.00
# 622  A paraplegic Marine dispatched to the moon Pan...       83.00
# 59   The Avengers and their allies must be willing ...       68.00
# 651  A seventeen-year-old aristocrat falls in love ...       75.00
# ..                                                 ...         ...
# 604  A quiet pawnshop keeper with a violent past ta...       79.00
# 925  A disaffected soldier returns to his hometown ...       52.00
# 623  A boy stands on a station platform as a train ...       63.00
# 389  Two terminally ill patients escape from a hosp...       79.00
# 629  A neo-nazi sentenced to community service at a...       51.00
#
#                  director              star1              star2  \
# 476           J.J. Abrams       Daisy Ridley        John Boyega
# 58          Anthony Russo          Joe Russo  Robert Downey Jr.
# 622         James Cameron    Sam Worthington        Zoe Saldana
# 59          Anthony Russo          Joe Russo  Robert Downey Jr.
# 651         James Cameron  Leonardo DiCaprio       Kate Winslet
# ..                    ...                ...                ...
# 604        Jeong-beom Lee            Won Bin        Sae-ron Kim
# 925         Shane Meadows    Paddy Considine       Gary Stretch
# 623      Jaco Van Dormael         Jared Leto       Sarah Polley
# 389           Thomas Jahn      Til Schweiger  Jan Josef Liefers
# 629  Anders Thomas Jensen     Ulrich Thomsen     Mads Mikkelsen
#
#                    star3               star4  no_of_votes          gross  \
# 476          Oscar Isaac    Domhnall Gleeson       860823 936,662,225.00
# 58           Chris Evans        Mark Ruffalo       809955 858,373,000.00
# 622     Sigourney Weaver  Michelle Rodriguez      1118998 760,507,625.00
# 59       Chris Hemsworth        Mark Ruffalo       834477 678,815,482.00
# 651           Billy Zane         Kathy Bates      1046089 659,325,379.00
# ..                   ...                 ...          ...            ...
# 604         Tae-hoon Kim         Hee-won Kim        62848       6,460.00
# 925         Toby Kebbell    Stuart Wolfenden        49728       6,013.00
# 623         Diane Kruger       Linh Dan Pham       216421       3,600.00
# 389  Thierry van Werveke    Moritz Bleibtreu        27721       3,296.00
# 629          Nicolas Bro       Paprika Steen        45717       1,305.00
#
#      decade
# 476    2010
# 58     2010
# 622    2000
# 59     2010
# 651    1990
# ..      ...
# 604    2010
# 925    2000
# 623    2000
# 389    1990
# 629    2000
#
# [998 rows x 17 columns]

# %% [markdown]
# ### Conclusão

# %% [markdown]
# Aventura é o gênero com maior potencial lucrativo, no entanto, existem outras questões pertinentes para serem consideradas na decisão de escolha de um projeto para investir, como sequências de filmes. Da lista acima, como destacado anteriormente, a maioria dos filmes pertence a uma sequência.
#
# Pode ser interessante uma análise mais aprofundada no recorte de filmes pertencentes a sequências.
